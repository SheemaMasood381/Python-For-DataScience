# %% [markdown]
# # Using Pandas

# %%
import csv
import pandas as pd

# %%
data_list = pd.read_csv("whitehouse_visitors.csv")

# %%
data_list.shape
# Out:
# (47954, 8)

# %%
data_list
# Out:
#                      name       appt_made_date appt_start_date  \
# 0       Joshua T. Blanton  2014-12-18T00:00:00     1/6/15 9:30
# 1         Jack T. Gutting  2014-12-18T00:00:00     1/6/15 9:30
# 2       Bradley T. Guiles  2014-12-18T00:00:00     1/6/15 9:30
# 3          Loryn F. Grieb  2014-12-18T00:00:00     1/6/15 9:30
# 4        Travis D. Gordon  2014-12-18T00:00:00     1/6/15 9:30
# ...                   ...                  ...             ...
# 47949  William B. Henline  2015-12-16T00:00:00  12/18/15 16:30
# 47950       Ian T. Burris  2015-12-16T00:00:00  12/18/15 16:30
# 47951    James F. Albaugh  2015-12-16T00:00:00  12/18/15 16:30
# 47952    Jackie L. Finken  2015-12-16T00:00:00  12/18/15 16:30
# 47953     Grace M. Bauman  2015-12-16T00:00:00  12/18/15 16:30
#
#         appt_end_date visitee_namelast visitee_namefirst meeting_room  \
# 0        1/6/15 23:59              NaN             potus    west wing
# ...

# %%
data_list["name"]
# Out:
# 0         Joshua T. Blanton
# 1           Jack T. Gutting
# 2         Bradley T. Guiles
# 3            Loryn F. Grieb
# 4          Travis D. Gordon
#                 ...
# 47949    William B. Henline
# 47950         Ian T. Burris
# 47951      James F. Albaugh
# 47952      Jackie L. Finken
# 47953       Grace M. Bauman
# Name: name, Length: 47954, dtype: object

# %%
data_list.iloc[0] # Integer / Index Location
# Out:
# name                                 Joshua T. Blanton
# appt_made_date                     2014-12-18T00:00:00
# appt_start_date                            1/6/15 9:30
# appt_end_date                             1/6/15 23:59
# visitee_namelast                                   NaN
# visitee_namefirst                                potus
# meeting_room                                 west wing
# description          JointService Military Honor Guard
# Name: 0, dtype: object

# %%
data_list.loc[47949] # Lable Location
# Out:
# name                  William B. Henline
# appt_made_date       2015-12-16T00:00:00
# appt_start_date           12/18/15 16:30
# appt_end_date             12/18/15 23:59
# visitee_namelast                     NaN
# visitee_namefirst           POTUS/FLOTUS
# meeting_room                  State Floo
# description                          NaN
# Name: 47949, dtype: object

# %%
data_list.head()
# Out:
#                 name       appt_made_date appt_start_date appt_end_date  \
# 0  Joshua T. Blanton  2014-12-18T00:00:00     1/6/15 9:30  1/6/15 23:59
# 1    Jack T. Gutting  2014-12-18T00:00:00     1/6/15 9:30  1/6/15 23:59
# 2  Bradley T. Guiles  2014-12-18T00:00:00     1/6/15 9:30  1/6/15 23:59
# 3     Loryn F. Grieb  2014-12-18T00:00:00     1/6/15 9:30  1/6/15 23:59
# 4   Travis D. Gordon  2014-12-18T00:00:00     1/6/15 9:30  1/6/15 23:59
#
#   visitee_namelast visitee_namefirst meeting_room  \
# 0              NaN             potus    west wing
# 1              NaN             potus    west wing
# 2              NaN             potus    west wing
# 3              NaN             potus    west wing
# 4              NaN             potus    west wing
#
#                          description
# 0  JointService Military Honor Guard
# 1  JointService Military Honor Guard
# 2  JointService Military Honor Guard
# 3  JointService Military Honor Guard
# 4  JointService Military Honor Guard

# %%
data_list.tail()
# Out:
#                      name       appt_made_date appt_start_date  \
# 47949  William B. Henline  2015-12-16T00:00:00  12/18/15 16:30
# 47950       Ian T. Burris  2015-12-16T00:00:00  12/18/15 16:30
# 47951    James F. Albaugh  2015-12-16T00:00:00  12/18/15 16:30
# 47952    Jackie L. Finken  2015-12-16T00:00:00  12/18/15 16:30
# 47953     Grace M. Bauman  2015-12-16T00:00:00  12/18/15 16:30
#
#         appt_end_date visitee_namelast visitee_namefirst meeting_room  \
# 47949  12/18/15 23:59              NaN      POTUS/FLOTUS   State Floo
# 47950  12/18/15 23:59              NaN      POTUS/FLOTUS   State Floo
# 47951  12/18/15 23:59              NaN      POTUS/FLOTUS   State Floo
# 47952  12/18/15 23:59              NaN      POTUS/FLOTUS   State Floo
# 47953  12/18/15 23:59              NaN      POTUS/FLOTUS   State Floo
#
#       description
# 47949         NaN
# 47950         NaN
# 47951         NaN
# 47952         NaN
# 47953         NaN

# %% [markdown]
# # How Many Appointments in data set

# %% [markdown]
# ## Particular Date & Time

# %%
data_list["appt_start_date"].unique()
# Out:
# array(['1/6/15 9:30', '1/6/15 10:00', '1/6/15 10:30', ...,
#        '12/18/15 16:00', '12/18/15 16:10', '12/18/15 16:30'], dtype=object)

# %%
data_list["appt_start_date"].nunique()
# Out:
# 1174

# %%
appointments_by_date = data_list.groupby("appt_start_date").size().reset_index(name="num_appointments")
print(appointments_by_date)
# Out:
#      appt_start_date  num_appointments
# 0      1/10/15 11:00                13
# 1      1/12/15 10:55                 2
# 2      1/12/15 11:30                45
# 3      1/12/15 12:00                 2
# 4      1/12/15 12:30                 5
# ...              ...               ...
# 1169    9/8/15 11:30                 3
# 1170    9/8/15 12:00                 7
# 1171    9/8/15 12:15                 1
# 1172     9/8/15 9:30                92
# 1173    9/9/15 11:30                 5
#
# [1174 rows x 2 columns]

# %%
data_list["appt_start_date"].value_counts().sort_values(ascending=False) #sort_index()
# Out:
# appt_start_date
# 6/15/15 15:15     3064
# 6/17/15 18:00     1874
# 12/7/15 18:00     1374
# 12/15/15 13:30     811
# 12/10/15 18:00     778
#                   ...
# 2/11/15 16:00        1
# 5/6/15 12:00         1
# 6/29/15 13:35        1
# 6/29/15 14:15        1
# 4/17/15 15:08        1
# Name: count, Length: 1174, dtype: int64

# %% [markdown]
# ## Particular Date

# %%
import datetime as dt

# %%
date_format = "%m/%d/%y %H:%M"

# %%
data_list.head()
# Out:
#                 name       appt_made_date appt_start_date appt_end_date  \
# 0  Joshua T. Blanton  2014-12-18T00:00:00     1/6/15 9:30  1/6/15 23:59
# 1    Jack T. Gutting  2014-12-18T00:00:00     1/6/15 9:30  1/6/15 23:59
# 2  Bradley T. Guiles  2014-12-18T00:00:00     1/6/15 9:30  1/6/15 23:59
# 3     Loryn F. Grieb  2014-12-18T00:00:00     1/6/15 9:30  1/6/15 23:59
# 4   Travis D. Gordon  2014-12-18T00:00:00     1/6/15 9:30  1/6/15 23:59
#
#   visitee_namelast visitee_namefirst meeting_room  \
# 0              NaN             potus    west wing
# 1              NaN             potus    west wing
# 2              NaN             potus    west wing
# 3              NaN             potus    west wing
# 4              NaN             potus    west wing
#
#                          description
# 0  JointService Military Honor Guard
# 1  JointService Military Honor Guard
# 2  JointService Military Honor Guard
# 3  JointService Military Honor Guard
# 4  JointService Military Honor Guard

# %%
asd = pd.to_datetime(data_list["appt_start_date"], format=date_format)
#print(asd)
dis = asd.dt.normalize() # use to display without time
dis.value_counts().sort_values(ascending=False) #sort_index()
# Out:
# appt_start_date
# 2015-06-15    3246
# 2015-09-25    2112
# 2015-06-17    2002
# 2015-12-10    1706
# 2015-12-16    1639
#               ...
# 2015-07-12       2
# 2015-01-19       1
# 2015-12-05       1
# 2015-11-26       1
# 2015-08-21       1
# Name: count, Length: 193, dtype: int64

# %%
pd.to_datetime(data_list["appt_start_date"], format=date_format).dt.normalize()
# Out:
# 0       2015-01-06
# 1       2015-01-06
# 2       2015-01-06
# 3       2015-01-06
# 4       2015-01-06
#            ...
# 47949   2015-12-18
# 47950   2015-12-18
# 47951   2015-12-18
# 47952   2015-12-18
# 47953   2015-12-18
# Name: appt_start_date, Length: 47954, dtype: datetime64[ns]

# %% [markdown]
# # How many unique meeting rooms

# %%
data_list.head()
# Out:
#                 name       appt_made_date appt_start_date appt_end_date  \
# 0  Joshua T. Blanton  2014-12-18T00:00:00     1/6/15 9:30  1/6/15 23:59
# 1    Jack T. Gutting  2014-12-18T00:00:00     1/6/15 9:30  1/6/15 23:59
# 2  Bradley T. Guiles  2014-12-18T00:00:00     1/6/15 9:30  1/6/15 23:59
# 3     Loryn F. Grieb  2014-12-18T00:00:00     1/6/15 9:30  1/6/15 23:59
# 4   Travis D. Gordon  2014-12-18T00:00:00     1/6/15 9:30  1/6/15 23:59
#
#   visitee_namelast visitee_namefirst meeting_room  \
# 0              NaN             potus    west wing
# 1              NaN             potus    west wing
# 2              NaN             potus    west wing
# 3              NaN             potus    west wing
# 4              NaN             potus    west wing
#
#                          description
# 0  JointService Military Honor Guard
# 1  JointService Military Honor Guard
# 2  JointService Military Honor Guard
# 3  JointService Military Honor Guard
# 4  JointService Military Honor Guard

# %%
data_list.meeting_room.nunique() # Count the number
# Out:
# 148

# %%
unique_mr = data_list.meeting_room.unique() # Get the unique items
print(unique_mr)
# Out:
# ['west wing' 'Oval Offic' 'WEST WING' 'OVAL OFFIC' 'Cabinet Ro' 'WW Lobby'
#  'ew 206' 'RESIDENCE' 'The Roosev' 'Roosevelt' 'State Floo' 'state floo'
#  'ww/Oval Of' 'Oval offic' 'Doctors Of' 'SCA/Oval' 'Residence/' 'Oval'
#  'East Room' 'WW//Oval O' 'WW/Rooseve' 'WW/Oval Of' 'West Wing' 'EW 100'
#  'ww/Rooseve' 'WW/Oval' 'WW' 'OVAL' 'oval Offic' 'Lobby' 'WW/ROOSEVE'
#  'SCA' 'WH Sit Roo' 'South Cour' 'Situation' 'WW 2 FL' 'WW//Roosev'
#  'EEOB 350' 'south lawn' 'ww/OVAL' 'Ward Room' 'Map Room' 'Residence'
#  'Oval Priva' '428' 'Diplomatic' 'RR' 'State floo' 'Grand Foye'
#  'Oval / EW' 'Oval OFfice' 'Oval Office' 'Oval office' 'state floor'
#  'State Floor' 'ww/Oval Office' 'WW/Roosevelt Room' 'East Room/East Wing'
#  'oval' '430' 'Old Family Dining Ro' 'west wing drive' 'Cabinet Room'
#  'State Floor/East Rm' 'ROOSEVELT ROOM' 'Oval Pantr' '45' 'State Dini'
#  'Res/Blue R' 'EW 200' 'roosevelt' 'SOUTH LAWN' 'WW/OVAL' '350'
# ...

# %%
data_list
# Out:
#                      name       appt_made_date appt_start_date  \
# 0       Joshua T. Blanton  2014-12-18T00:00:00     1/6/15 9:30
# 1         Jack T. Gutting  2014-12-18T00:00:00     1/6/15 9:30
# 2       Bradley T. Guiles  2014-12-18T00:00:00     1/6/15 9:30
# 3          Loryn F. Grieb  2014-12-18T00:00:00     1/6/15 9:30
# 4        Travis D. Gordon  2014-12-18T00:00:00     1/6/15 9:30
# ...                   ...                  ...             ...
# 47949  William B. Henline  2015-12-16T00:00:00  12/18/15 16:30
# 47950       Ian T. Burris  2015-12-16T00:00:00  12/18/15 16:30
# 47951    James F. Albaugh  2015-12-16T00:00:00  12/18/15 16:30
# 47952    Jackie L. Finken  2015-12-16T00:00:00  12/18/15 16:30
# 47953     Grace M. Bauman  2015-12-16T00:00:00  12/18/15 16:30
#
#         appt_end_date visitee_namelast visitee_namefirst meeting_room  \
# 0        1/6/15 23:59   Not Applicable             potus    west wing
# ...
